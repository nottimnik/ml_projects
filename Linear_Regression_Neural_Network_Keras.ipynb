# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Download, explore & clean the dataset**
# Now, let's start by downloading our dataset and explore it a bit so we know with what we are working with.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# Okay, so we have a dataset with 9 features: Cement, Blast Furnace Slag, Fly Ash, Water, Superplasticizer, Coarse Aggregate, Fine Aggregate, Age, Strength. We want to predict the attribute Strength.
#
# Let's check how many data points we have

# %%
concrete_data.shape # we have 1030 samples
# Out:
# (1030, 9)

# %% [markdown]
# Let's check the dataset for any missing values

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks clean, so we are ready to be build our model.

# %% [markdown]
# # **Split the data into predictors and target**

# %%
predictors = concrete_data.drop(['Strength'], axis=1) # remove the Strength column from the dataFrame
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# Quick sanity check of our predictors and target:

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
n_cols = predictors_norm.shape[1] # number of predictors
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# # **Build our model with Keras**

# %%
import keras # import keras

# %%
# import the rest of the packages
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# We define a function the defines our regression model

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above model has two hidden layers each with 50 hidden nodes.

# %% [markdown]
# # **Train and Test the Network**

# %%
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 20% of the data for validation and we will train the model for 100 epochs.

# %%
model.fit(predictors_norm, target, validation_split=0.2, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 26/26 - 1s - loss: 1571.3706 - val_loss: 1144.1097 - 1s/epoch - 54ms/step
# Epoch 2/100
# 26/26 - 0s - loss: 1408.4474 - val_loss: 1009.3365 - 90ms/epoch - 3ms/step
# Epoch 3/100
# 26/26 - 0s - loss: 1123.6533 - val_loss: 795.1569 - 79ms/epoch - 3ms/step
# Epoch 4/100
# 26/26 - 0s - loss: 738.6453 - val_loss: 543.2873 - 98ms/epoch - 4ms/step
# Epoch 5/100
# 26/26 - 0s - loss: 422.3061 - val_loss: 355.2255 - 96ms/epoch - 4ms/step
# Epoch 6/100
# 26/26 - 0s - loss: 280.4122 - val_loss: 267.3870 - 91ms/epoch - 3ms/step
# Epoch 7/100
# 26/26 - 0s - loss: 237.1936 - val_loss: 239.3581 - 91ms/epoch - 4ms/step
# Epoch 8/100
# 26/26 - 0s - loss: 216.7279 - val_loss: 212.7437 - 100ms/epoch - 4ms/step
# Epoch 9/100
# 26/26 - 0s - loss: 203.1832 - val_loss: 206.5611 - 83ms/epoch - 3ms/step
# Epoch 10/100
# 26/26 - 0s - loss: 192.5727 - val_loss: 197.6523 - 95ms/epoch - 4ms/step
# Epoch 11/100
# 26/26 - 0s - loss: 184.1422 - val_loss: 186.6663 - 80ms/epoch - 3ms/step
# Epoch 12/100
# 26/26 - 0s - loss: 177.0787 - val_loss: 181.7531 - 83ms/epoch - 3ms/step
# Epoch 13/100
# 26/26 - 0s - loss: 171.2234 - val_loss: 179.7226 - 81ms/epoch - 3ms/step
# Epoch 14/100
# 26/26 - 0s - loss: 165.8935 - val_loss: 178.1193 - 90ms/epoch - 3ms/step
# Epoch 15/100
# 26/26 - 0s - loss: 161.5079 - val_loss: 175.1118 - 91ms/epoch - 4ms/step
# Epoch 16/100
# 26/26 - 0s - loss: 157.7293 - val_loss: 171.4119 - 90ms/epoch - 3ms/step
# Epoch 17/100
# 26/26 - 0s - loss: 154.8596 - val_loss: 168.4559 - 90ms/epoch - 3ms/step
# Epoch 18/100
# 26/26 - 0s - loss: 151.7384 - val_loss: 168.6100 - 84ms/epoch - 3ms/step
# Epoch 19/100
# 26/26 - 0s - loss: 148.7755 - val_loss: 170.9596 - 107ms/epoch - 4ms/step
# Epoch 20/100
# 26/26 - 0s - loss: 147.0243 - val_loss: 171.8231 - 83ms/epoch - 3ms/step
# Epoch 21/100
# 26/26 - 0s - loss: 145.3321 - val_loss: 166.9240 - 92ms/epoch - 4ms/step
# Epoch 22/100
# 26/26 - 0s - loss: 142.7706 - val_loss: 170.6876 - 94ms/epoch - 4ms/step
# Epoch 23/100
# 26/26 - 0s - loss: 139.8199 - val_loss: 168.9178 - 86ms/epoch - 3ms/step
# Epoch 24/100
# 26/26 - 0s - loss: 137.9255 - val_loss: 170.0263 - 92ms/epoch - 4ms/step
# Epoch 25/100
# 26/26 - 0s - loss: 136.7754 - val_loss: 170.6537 - 90ms/epoch - 3ms/step
# Epoch 26/100
# 26/26 - 0s - loss: 134.7597 - val_loss: 174.0860 - 92ms/epoch - 4ms/step
# Epoch 27/100
# 26/26 - 0s - loss: 132.8346 - val_loss: 176.7488 - 91ms/epoch - 4ms/step
# Epoch 28/100
# 26/26 - 0s - loss: 131.9140 - val_loss: 173.3288 - 91ms/epoch - 3ms/step
# Epoch 29/100
# 26/26 - 0s - loss: 130.2343 - val_loss: 172.8187 - 81ms/epoch - 3ms/step
# Epoch 30/100
# 26/26 - 0s - loss: 128.9968 - val_loss: 176.8203 - 109ms/epoch - 4ms/step
# Epoch 31/100
# 26/26 - 0s - loss: 127.0816 - val_loss: 176.0615 - 91ms/epoch - 3ms/step
# Epoch 32/100
# 26/26 - 0s - loss: 125.8956 - val_loss: 179.0275 - 83ms/epoch - 3ms/step
# Epoch 33/100
# 26/26 - 0s - loss: 124.6031 - val_loss: 180.7045 - 80ms/epoch - 3ms/step
# Epoch 34/100
# 26/26 - 0s - loss: 123.4061 - val_loss: 178.0452 - 87ms/epoch - 3ms/step
# Epoch 35/100
# 26/26 - 0s - loss: 122.3083 - val_loss: 180.9618 - 79ms/epoch - 3ms/step
# Epoch 36/100
# 26/26 - 0s - loss: 121.0912 - val_loss: 181.2773 - 88ms/epoch - 3ms/step
# Epoch 37/100
# 26/26 - 0s - loss: 119.4090 - val_loss: 177.5896 - 91ms/epoch - 3ms/step
# Epoch 38/100
# 26/26 - 0s - loss: 118.9948 - val_loss: 180.9370 - 90ms/epoch - 3ms/step
# Epoch 39/100
# 26/26 - 0s - loss: 117.1286 - val_loss: 181.9859 - 78ms/epoch - 3ms/step
# Epoch 40/100
# 26/26 - 0s - loss: 116.9222 - val_loss: 188.2648 - 86ms/epoch - 3ms/step
# Epoch 41/100
# 26/26 - 0s - loss: 114.0573 - val_loss: 182.2867 - 94ms/epoch - 4ms/step
# Epoch 42/100
# 26/26 - 0s - loss: 112.4924 - val_loss: 180.3326 - 88ms/epoch - 3ms/step
# Epoch 43/100
# 26/26 - 0s - loss: 110.6278 - val_loss: 176.2517 - 81ms/epoch - 3ms/step
# Epoch 44/100
# 26/26 - 0s - loss: 109.1233 - val_loss: 178.8420 - 81ms/epoch - 3ms/step
# Epoch 45/100
# 26/26 - 0s - loss: 107.1231 - val_loss: 179.5964 - 83ms/epoch - 3ms/step
# Epoch 46/100
# 26/26 - 0s - loss: 103.7027 - val_loss: 171.0036 - 90ms/epoch - 3ms/step
# Epoch 47/100
# 26/26 - 0s - loss: 101.5724 - val_loss: 169.9441 - 81ms/epoch - 3ms/step
# Epoch 48/100
# 26/26 - 0s - loss: 99.1852 - val_loss: 172.3210 - 82ms/epoch - 3ms/step
# Epoch 49/100
# 26/26 - 0s - loss: 96.3910 - val_loss: 170.1463 - 82ms/epoch - 3ms/step
# Epoch 50/100
# 26/26 - 0s - loss: 93.9609 - val_loss: 166.4098 - 83ms/epoch - 3ms/step
# Epoch 51/100
# 26/26 - 0s - loss: 90.2315 - val_loss: 171.5172 - 77ms/epoch - 3ms/step
# Epoch 52/100
# 26/26 - 0s - loss: 86.8551 - val_loss: 164.2462 - 78ms/epoch - 3ms/step
# Epoch 53/100
# 26/26 - 0s - loss: 84.0761 - val_loss: 165.0464 - 99ms/epoch - 4ms/step
# Epoch 54/100
# 26/26 - 0s - loss: 80.9773 - val_loss: 157.8000 - 90ms/epoch - 3ms/step
# Epoch 55/100
# 26/26 - 0s - loss: 78.1312 - val_loss: 159.4415 - 92ms/epoch - 4ms/step
# Epoch 56/100
# 26/26 - 0s - loss: 74.8607 - val_loss: 156.0662 - 82ms/epoch - 3ms/step
# Epoch 57/100
# 26/26 - 0s - loss: 71.5798 - val_loss: 160.6182 - 78ms/epoch - 3ms/step
# Epoch 58/100
# 26/26 - 0s - loss: 68.1855 - val_loss: 148.1183 - 104ms/epoch - 4ms/step
# Epoch 59/100
# 26/26 - 0s - loss: 65.3517 - val_loss: 162.2606 - 81ms/epoch - 3ms/step
# Epoch 60/100
# 26/26 - 0s - loss: 62.3779 - val_loss: 148.8342 - 91ms/epoch - 4ms/step
# Epoch 61/100
# 26/26 - 0s - loss: 59.7542 - val_loss: 158.4513 - 91ms/epoch - 3ms/step
# Epoch 62/100
# 26/26 - 0s - loss: 57.0537 - val_loss: 148.7715 - 90ms/epoch - 3ms/step
# Epoch 63/100
# 26/26 - 0s - loss: 55.2368 - val_loss: 141.9651 - 95ms/epoch - 4ms/step
# Epoch 64/100
# 26/26 - 0s - loss: 53.0849 - val_loss: 152.8487 - 92ms/epoch - 4ms/step
# Epoch 65/100
# 26/26 - 0s - loss: 51.7713 - val_loss: 156.0294 - 82ms/epoch - 3ms/step
# Epoch 66/100
# 26/26 - 0s - loss: 50.1643 - val_loss: 145.7898 - 79ms/epoch - 3ms/step
# Epoch 67/100
# 26/26 - 0s - loss: 48.5911 - val_loss: 155.5828 - 85ms/epoch - 3ms/step
# Epoch 68/100
# 26/26 - 0s - loss: 48.0641 - val_loss: 146.1127 - 88ms/epoch - 3ms/step
# Epoch 69/100
# 26/26 - 0s - loss: 46.9306 - val_loss: 151.7940 - 78ms/epoch - 3ms/step
# Epoch 70/100
# 26/26 - 0s - loss: 45.7682 - val_loss: 151.4225 - 90ms/epoch - 3ms/step
# Epoch 71/100
# 26/26 - 0s - loss: 45.3236 - val_loss: 152.2876 - 93ms/epoch - 4ms/step
# Epoch 72/100
# 26/26 - 0s - loss: 44.1700 - val_loss: 152.6828 - 93ms/epoch - 4ms/step
# Epoch 73/100
# 26/26 - 0s - loss: 43.1517 - val_loss: 155.9171 - 79ms/epoch - 3ms/step
# Epoch 74/100
# 26/26 - 0s - loss: 42.0125 - val_loss: 151.0763 - 80ms/epoch - 3ms/step
# Epoch 75/100
# 26/26 - 0s - loss: 41.6791 - val_loss: 156.4215 - 104ms/epoch - 4ms/step
# Epoch 76/100
# 26/26 - 0s - loss: 40.9966 - val_loss: 147.6183 - 94ms/epoch - 4ms/step
# Epoch 77/100
# 26/26 - 0s - loss: 41.9947 - val_loss: 149.6983 - 95ms/epoch - 4ms/step
# Epoch 78/100
# 26/26 - 0s - loss: 40.3082 - val_loss: 164.2213 - 104ms/epoch - 4ms/step
# Epoch 79/100
# 26/26 - 0s - loss: 39.4484 - val_loss: 164.5537 - 85ms/epoch - 3ms/step
# Epoch 80/100
# 26/26 - 0s - loss: 38.4752 - val_loss: 160.4254 - 93ms/epoch - 4ms/step
# Epoch 81/100
# 26/26 - 0s - loss: 37.9853 - val_loss: 166.4875 - 100ms/epoch - 4ms/step
# Epoch 82/100
# 26/26 - 0s - loss: 37.8155 - val_loss: 160.2330 - 92ms/epoch - 4ms/step
# Epoch 83/100
# 26/26 - 0s - loss: 37.7198 - val_loss: 174.3300 - 97ms/epoch - 4ms/step
# Epoch 84/100
# 26/26 - 0s - loss: 37.4113 - val_loss: 170.1971 - 96ms/epoch - 4ms/step
# Epoch 85/100
# 26/26 - 0s - loss: 36.5831 - val_loss: 156.7898 - 104ms/epoch - 4ms/step
# Epoch 86/100
# 26/26 - 0s - loss: 36.4171 - val_loss: 169.8349 - 146ms/epoch - 6ms/step
# Epoch 87/100
# 26/26 - 0s - loss: 36.1908 - val_loss: 165.9486 - 141ms/epoch - 5ms/step
# Epoch 88/100
# 26/26 - 0s - loss: 35.7624 - val_loss: 165.5960 - 124ms/epoch - 5ms/step
# Epoch 89/100
# 26/26 - 0s - loss: 35.8803 - val_loss: 164.3537 - 125ms/epoch - 5ms/step
# Epoch 90/100
# 26/26 - 0s - loss: 34.8857 - val_loss: 175.0589 - 124ms/epoch - 5ms/step
# Epoch 91/100
# 26/26 - 0s - loss: 35.0388 - val_loss: 166.1059 - 111ms/epoch - 4ms/step
# Epoch 92/100
# 26/26 - 0s - loss: 34.6890 - val_loss: 157.6532 - 114ms/epoch - 4ms/step
# Epoch 93/100
# 26/26 - 0s - loss: 34.9764 - val_loss: 178.3564 - 155ms/epoch - 6ms/step
# Epoch 94/100
# 26/26 - 0s - loss: 33.9536 - val_loss: 169.1862 - 125ms/epoch - 5ms/step
# Epoch 95/100
# 26/26 - 0s - loss: 33.6911 - val_loss: 170.6489 - 106ms/epoch - 4ms/step
# Epoch 96/100
# 26/26 - 0s - loss: 33.7304 - val_loss: 180.1266 - 113ms/epoch - 4ms/step
# Epoch 97/100
# 26/26 - 0s - loss: 33.1822 - val_loss: 167.3667 - 118ms/epoch - 5ms/step
# Epoch 98/100
# 26/26 - 0s - loss: 33.1953 - val_loss: 173.8889 - 117ms/epoch - 5ms/step
# Epoch 99/100
# 26/26 - 0s - loss: 32.6301 - val_loss: 168.6024 - 119ms/epoch - 5ms/step
# Epoch 100/100
# 26/26 - 0s - loss: 33.1889 - val_loss: 172.1237 - 121ms/epoch - 5ms/step

# %% [markdown]
# And.. that's it! This is how we can create a regression model with keras, we can now make predictions:

# %%
means = np.array([2.476712, -0.856472, -0.846733, -0.916319, -0.620147, 0.862735, -1.217079, -0.279597])
std_devs = np.array([0.797405, 0.418344, 0.450949, 0.584833, 0.586064, 0.475220, 0.154757, 0.110175])

# Create an input example
input_example = np.array([2.5, -0.9, -0.8, -0.9, -0.6, 0.9, -1.2, -0.2])

# Normalize the input using the same mean and standard deviation
normalized_input = (input_example - means) / std_devs

# Reshape the input to match the model's expected input shape
normalized_input = normalized_input.reshape(1, -1)

# Assuming 'model' is your trained Sequential model
predictions = model.predict(normalized_input)

print(predictions)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# [[39.816776]]
